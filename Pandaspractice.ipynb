# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'
# Out:
# Hello Google Drive!

# %%
import pandas as pd

df = pd.read_csv("https://github.com/simplydivs/pandas/raw/master/pokemon_data.csv")
print(df)
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df.head(10)
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 0  1                  Bulbasaur  Grass  ...    45           1      False
# 1  2                    Ivysaur  Grass  ...    60           1      False
# 2  3                   Venusaur  Grass  ...    80           1      False
# 3  3      VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4                 Charmander   Fire  ...    65           1      False
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
#
# [10 rows x 12 columns]

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 790  714               Noibat   Flying  ...    55           6      False
# 791  715              Noivern   Flying  ...   123           6      False
# 792  716              Xerneas    Fairy  ...    99           6       True
# 793  717              Yveltal     Dark  ...    99           6       True
# 794  718     Zygarde50% Forme   Dragon  ...    95           6       True
# 795  719              Diancie     Rock  ...    50           6       True
# 796  719  DiancieMega Diancie     Rock  ...   110           6       True
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [10 rows x 12 columns]

# %%
#if u wanna know headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#if u wanna play with coloumns
df[['Name', 'Type 1', 'Attack', 'Speed']][:10]
# Out:
#                         Name Type 1  Attack  Speed
# 0                  Bulbasaur  Grass      49     45
# 1                    Ivysaur  Grass      62     60
# 2                   Venusaur  Grass      82     80
# 3      VenusaurMega Venusaur  Grass     100     80
# 4                 Charmander   Fire      52     65
# 5                 Charmeleon   Fire      64     80
# 6                  Charizard   Fire      84    100
# 7  CharizardMega Charizard X   Fire     130    100
# 8  CharizardMega Charizard Y   Fire     104    100
# 9                   Squirtle  Water      48     43

# %%
#if u wanna play with rows
df.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
#if u wanna know every info of a particular row
#df.iloc[1:30:2]
df.iloc[:30:2, ::2]
# Out:
#      #  Type 1  HP  Defense  Sp. Def  Generation
# 0    1   Grass  45       49       65           1
# 2    3   Grass  80       83      100           1
# 4    4    Fire  39       43       50           1
# 6    6    Fire  78       78       85           1
# 8    6    Fire  78       78      115           1
# 10   8   Water  59       80       80           1
# 12   9   Water  79      120      115           1
# 14  11     Bug  50       55       25           1
# 16  13     Bug  40       30       20           1
# 18  15     Bug  65       40       80           1
# 20  16  Normal  40       40       35           1
# 22  18  Normal  83       75       70           1
# 24  19  Normal  30       35       35           1
# 26  21  Normal  40       30       31           1
# 28  23  Poison  35       44       54           1

# %%
#if u wanna discuss about particular attribute like "print those who have HP>140" or "filtering data"
#df.loc[df['HP']>140]
#for filtering multiple data as
df = df.loc[(df["Attack"]>50) & (df["Defense"]<70)]
df.head()
# Out:
#      #                   Name Type 1  ... Speed  Generation  Legendary
# 1    2                Ivysaur  Grass  ...    60           1      False
# 4    4             Charmander   Fire  ...    65           1      False
# 5    5             Charmeleon   Fire  ...    80           1      False
# 18  15               Beedrill    Bug  ...    75           1      False
# 19  15  BeedrillMega Beedrill    Bug  ...   145           1      False
#
# [5 rows x 12 columns]

# %%
#To get some stats about the dataset
df.describe()
# Out:
#                 #          HP      Attack  ...     Sp. Def       Speed  Generation
# count  250.000000  250.000000  250.000000  ...  250.000000  250.000000  250.000000
# mean   358.424000   64.924000   79.436000  ...   59.220000   71.428000    3.384000
# std    207.648443   22.349502   23.804549  ...   21.619092   27.908284    1.675642
# min      2.000000    1.000000   51.000000  ...   20.000000    5.000000    1.000000
# 25%    193.750000   50.000000   62.000000  ...   45.000000   50.500000    2.000000
# 50%    359.000000   62.000000   73.500000  ...   55.000000   68.000000    3.000000
# 75%    522.750000   73.000000   90.000000  ...   65.000000   90.000000    5.000000
# max    720.000000  170.000000  180.000000  ...  154.000000  160.000000    6.000000
#
# [8 rows x 8 columns]

# %%
#if u wanna sort values
df.sort_values("Name", ascending=False)
# Out:
#        #                  Name    Type 1  ... Speed  Generation  Legendary
# 631  570                 Zorua      Dark  ...    65           5      False
# 632  571               Zoroark      Dark  ...   105           5      False
# 582  523             Zebstrika  Electric  ...   116           5      False
# 367  335              Zangoose    Normal  ...    90           3      False
# 208  193                 Yanma       Bug  ...    95           2      False
# ..   ...                   ...       ...  ...   ...         ...        ...
# 153  142            Aerodactyl      Rock  ...   130           1      False
# 750  681  AegislashBlade Forme     Steel  ...    60           6      False
# 678  617              Accelgor       Bug  ...   145           5      False
# 393  359       AbsolMega Absol      Dark  ...   115           3      False
# 392  359                 Absol      Dark  ...    75           3      False
#
# [250 rows x 12 columns]

# %%
#if u wanna sort multiple values "first attribute in ascending order and the second one in descending order"
df.sort_values(["HP","Attack"], ascending=[1,0] )
# Out:
#        #        Name    Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 316  292    Shedinja       Bug   Ghost  ...       30     40           3      False
# 55    50     Diglett    Ground     NaN  ...       45     95           1      False
# 24    19     Rattata    Normal     NaN  ...       35     72           1      False
# 91    84       Doduo    Normal  Flying  ...       35     75           1      False
# 56    51     Dugtrio    Ground     NaN  ...       70    120           1      False
# ..   ...         ...       ...     ...  ...      ...    ...         ...        ...
# 45    40  Wigglytuff    Normal   Fairy  ...       50     45           1      False
# 321  297    Hariyama  Fighting     NaN  ...       60     50           3      False
# 473  426    Drifblim     Ghost  Flying  ...       54     80           4      False
# 155  143     Snorlax    Normal     NaN  ...      110     30           1      False
# ...

# %%
#add a new column
df = pd.read_csv("https://github.com/simplydivs/pandas/raw/master/pokemon_data.csv")
df
df["Total"] = df.iloc[:, 4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  ...  Speed  Generation  Legendary  Total
# 0  1              Bulbasaur  Grass  Poison  ...     45           1      False    318
# 1  2                Ivysaur  Grass  Poison  ...     60           1      False    405
# 2  3               Venusaur  Grass  Poison  ...     80           1      False    525
# 3  3  VenusaurMega Venusaur  Grass  Poison  ...     80           1      False    625
# 4  4             Charmander   Fire     NaN  ...     65           1      False    309
#
# [5 rows x 13 columns]

# %%
#move any column"suppose moving last column"
cols = list(df.columns)
df = df[cols[:4]+[cols[-1]]+cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 13 columns]

# %%
df.to_csv("modified.csv", index=False)
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]

# %%
cools = list(df.columns)
df = df[cools[0:4]+cools[5:] +[cools[4]]]
df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  ...          1      False    318
# 1      2                Ivysaur    Grass  ...          1      False    405
# 2      3               Venusaur    Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    625
# 4      4             Charmander     Fire  ...          1      False    309
# ..   ...                    ...      ...  ...        ...        ...    ...
# 795  719                Diancie     Rock  ...          6       True    600
# 796  719    DiancieMega Diancie     Rock  ...          6       True    700
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True    600
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True    680
# 799  721              Volcanion     Fire  ...          6       True    600
#
# [800 rows x 13 columns]

# %%
df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  ...          1      False    318
# 1      2                Ivysaur    Grass  ...          1      False    405
# 2      3               Venusaur    Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    625
# 4      4             Charmander     Fire  ...          1      False    309
# ..   ...                    ...      ...  ...        ...        ...    ...
# 795  719                Diancie     Rock  ...          6       True    600
# 796  719    DiancieMega Diancie     Rock  ...          6       True    700
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True    600
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True    680
# 799  721              Volcanion     Fire  ...          6       True    600
#
# [800 rows x 13 columns]

# %%
#filtering data
df = df.loc[(df["Attack"]>50) & (df["Defense"]<70)]
df.head()
# Out:
#      #                   Name Type 1  ... Generation  Legendary  Total
# 1    2                Ivysaur  Grass  ...          1      False    405
# 4    4             Charmander   Fire  ...          1      False    309
# 5    5             Charmeleon   Fire  ...          1      False    405
# 18  15               Beedrill    Bug  ...          1      False    395
# 19  15  BeedrillMega Beedrill    Bug  ...          1      False    495
#
# [5 rows x 13 columns]

# %%
#reset index of the following"drop means removal of column""
df.reset_index(drop = True).head()
# Out:
#     #                   Name Type 1  ... Generation  Legendary  Total
# 0   2                Ivysaur  Grass  ...          1      False    405
# 1   4             Charmander   Fire  ...          1      False    309
# 2   5             Charmeleon   Fire  ...          1      False    405
# 3  15               Beedrill    Bug  ...          1      False    395
# 4  15  BeedrillMega Beedrill    Bug  ...          1      False    495
#
# [5 rows x 13 columns]

# %%
#df = df.loc[~df["Name"].str.contains("Mega")]
#df.reset_index(drop=True).head(20)

# %%
#if u wanna change attribute of a particular as
df = pd.read_csv("https://github.com/simplydivs/pandas/raw/master/pokemon_data.csv")
df

#df = df.loc[df["Type 1"] == "Fire", "Type 1"] = "Flammer"
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df.groupby(["Type 1"]).sum()
# Out:
#               #    HP  Attack  Defense  ...  Sp. Def  Speed  Generation  Legendary
# Type 1                                  ...
# Bug       23080  3925    4897     4880  ...     4471   4256         222        0.0
# Dark      14302  2071    2740     2177  ...     2155   2361         125        2.0
# Dragon    15180  2666    3588     2764  ...     2843   2657         124       12.0
# Electric  15994  2631    3040     2917  ...     3243   3718         144        4.0
# Fairy      7642  1260    1046     1117  ...     1440    826          70        1.0
# Fighting   9824  1886    2613     1780  ...     1747   1784          91        0.0
# Fire      17025  3635    4408     3524  ...     3755   3871         167        5.0
# Flying     2711   283     315      265  ...      290    410          22        2.0
# Ghost     15568  2062    2361     2598  ...     2447   2059         134        2.0
# Grass     24141  4709    5125     4956  ...     4930   4335         235        3.0
# ...

# %%
df.to_csv("modified1.csv", index=False)
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]
